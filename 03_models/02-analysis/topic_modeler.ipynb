# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                    Name  \
# 0       -1   6496                        -1_to_the_and_of
# 1        0   1840                    0_game_team_games_he
# 2        1    601           1_key_clipper_chip_encryption
# 3        2    532                   2_ites_hello_cheek_hi
# 4        3    481              3_israel_israeli_jews_arab
# ..     ...    ...                                     ...
# 221    220     10               220_phone_onhook_tip_ring
# 222    221     10       221_techworks_sales_warranty_mail
# 223    222     10        222_memory_shared_server_pixmaps
# 224    223     10  223_media_publications_spiking_digging
# 225    224     10       224_cesarean_disease_malaria_lyme
#
#                                         Representation  \
# 0       [to, the, and, of, is, for, you, in, it, this]
# 1    [game, team, games, he, players, season, hocke...
# 2    [key, clipper, chip, encryption, keys, escrow,...
# 3    [ites, hello, cheek, hi, yep, huh, ken, forget...
# 4    [israel, israeli, jews, arab, jewish, arabs, p...
# ..                                                 ...
# 221  [phone, onhook, tip, ring, lines, led, wires, ...
# 222  [techworks, sales, warranty, mail, dealers, se...
# 223  [memory, shared, server, pixmaps, xputimage, e...
# 224  [media, publications, spiking, digging, ommitt...
# 225  [cesarean, disease, malaria, lyme, health, hae...
#
#                                    Representative_Docs
# 0    [[does he believe in predestination]\n\nreally...
# 1    [Apparently, Part 2 (defensemen numbered 2 thr...
# 2    [Here are some corrections and additions to He...
# 3    [Hi,, \n \n                                   ...
# 4    [\nThis a "tried and true" method utilized by ...
# ..                                                 ...
# 221  [I've got two lines coming into my apartment. ...
# 222  [\n    ^^^\nHow long does he have to take in f...
# 223  [\n  There's documentation on how to use the s...
# 224  [\n\n\nIs this the same Monolithic, Centrally ...
# 225  [\n\nI am one of those people who always willl...
#
# [226 rows x 5 columns]

# %%
docs[0]
# Out:
# "\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n"
